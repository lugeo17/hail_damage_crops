# %%
from sentinelhub import SHConfig

config = SHConfig()

if not config.sh_client_id or not config.sh_client_secret:
    print("Warning! To use Process API, please provide the credentials (OAuth client ID and client secret).")

# %% [markdown]
# # Imports

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import datetime
import os

import matplotlib.pyplot as plt
import numpy as np
from utils import plot_image
from utils2 import plot_image2
from mpl_toolkits.axes_grid1 import make_axes_locatable
from plotImage import *
from osgeo import gdal

from sentinelhub import (
    SentinelHubStatistical,
    CRS,
    BBox,
    DataCollection,
    DownloadRequest,
    MimeType,
    MosaickingOrder,
    SentinelHubDownloadClient,
    SentinelHubRequest,
    bbox_to_dimensions,
    Geometry, 
    SHConfig, 
    parse_time, 
    parse_time_interval, 
    SentinelHubStatisticalDownloadClient    
)

# %% [markdown]
# # NDVI

# %% [markdown]
# NDVI July 3

# %%
#evalscript for ndvi calculation
evalscript_ndvi = """
    VERSION=3
    function setup() {
      return{
        input: [{
          bands: ["B04", "B08"],
          units: "DN"
        }],
        output: {
          id: "default",
          bands: 1,
          sampleType: SampleType.FLOAT32
        }
      }
    }
    
    function evaluatePixel(sample) {
      let ndvi = (sample.B08 - sample.B04) / (sample.B08 + sample.B04)
      return [ ndvi ]     
}   
"""

# %%
#evalscript for statistics calculation
evalscript_statistics = """
//VERSION=3
function setup() {
  return {
    input: [{
      bands: [
        "B04",
        "B08",
        "SCL",
        "dataMask"
      ]
    }],
    output: [
      {
        id: "ndvi",
        bands: ["NDVI"]
      },
      {
        id: "dataMask",
        bands: 1
      }]
  }
}


function evaluatePixel(samples) {
    let ndvi = (samples.B08 - samples.B04)/(samples.B08 + samples.B04)
    
    var validNDVIMask = 1
    if (samples.B04 + samples.B08 == 0 ){ //check if all the bands are 0
        validNDVIMask = 0
    }
    
    var noWaterMask = 1
    if (samples.SCL == 6 ){ //check if pixels are classified as water using SCL band
        noWaterMask = 0
    }

    return {
        ndvi: [ndvi],
        dataMask: [samples.dataMask * validNDVIMask * noWaterMask]  //if even one of the three exclusion criteria is 0, the pixel will be excluded
    }
}

"""

calculations = {
    "default": {
        "statistics": {
            "default": {
                "percentiles": {
                    "k": [],
                    "interpolation": "higher"
                }
            }
        }
    }
}

# %%
bbox = BBox(bbox=[-106.25547, 49.56475, -105.92777, 49.66729], crs=CRS.WGS84)

request = SentinelHubRequest(
    evalscript=evalscript_ndvi,
    input_data=[
        SentinelHubRequest.input_data(
            data_collection=DataCollection.SENTINEL2_L2A,          
            time_interval=('2020-07-03', '2020-07-03'),          
            other_args={"dataFilter": {"mosaickingOrder": "mostRecent"}}
        ),
    ],
    responses=[
        SentinelHubRequest.output_response('default', MimeType.TIFF),
    ],
    bbox=bbox,
    size=[512, 247.012],
    config=config
)

response = request.get_data()

# %%
ndvi_july3 = response[0]

# %%
plotImage (ndvi_july3)

# %% [markdown]
# NDVI July 3 statistics

# %%
bbox = BBox(bbox=[-106.25547, 49.56475, -105.92777, 49.66729], crs=CRS.WGS84)

request = SentinelHubStatistical(
    aggregation=SentinelHubStatistical.aggregation(
        evalscript=evalscript_statistics,
        time_interval=('2020-07-03T00:00:00Z', '2020-07-04T23:59:59Z'),
        aggregation_interval='P1D',
        size=[512, 247.012],        
    ),
    input_data=[
        SentinelHubStatistical.input_data(
            DataCollection.SENTINEL2_L2A,                        
      ),
    ],
    bbox=bbox,
    calculations=calculations,
    config=config
)

statistics = request.get_data()
statistics
# Out:
# [{'data': [{'interval': {'from': '2020-07-03T00:00:00Z',
#      'to': '2020-07-04T00:00:00Z'},
#     'outputs': {'ndvi': {'bands': {'NDVI': {'stats': {'min': -1.0,
#          'max': 0.949702799320221,
#          'mean': 0.5882676384611676,
#          'stDev': 0.17112226830220073,
#          'sampleCount': 126464,
#          'noDataCount': 4180,
#          'percentiles': {}}}}}}}],
#   'status': 'OK'}]

# %% [markdown]
# NDVI calculation 2 days after the event (2020.07.06)

# %%
bbox = BBox(bbox=[-106.25547, 49.56475, -105.92777, 49.66729], crs=CRS.WGS84)

request = SentinelHubRequest(
    evalscript=evalscript_ndvi,
    input_data=[
        SentinelHubRequest.input_data(
            data_collection=DataCollection.SENTINEL2_L2A,          
            time_interval=('2020-07-06', '2020-07-06'),          
            other_args={"dataFilter": {"mosaickingOrder": "mostRecent"}}
        ),
    ],
    responses=[
        SentinelHubRequest.output_response('default', MimeType.TIFF),
    ],
    bbox=bbox,
    size=[512, 247.012],
    config=config
)

response1 = request.get_data()

# %%
ndvi_july6 = response1[0]
plotImage(ndvi_july6)

# %% [markdown]
# Change detection

# %%
NDVIchange = (response[0]-response1[0])/((response[0]+response1[0]))
min_NDVIchange = np.min(NDVIchange)
max_NDVIchange = np.max(NDVIchange)

print('Minimum value NDVI difference is:', min_NDVIchange)
print('Maximum value NDVI difference is:', max_NDVIchange)

NDVIchange
# Out:
# Minimum value NDVI difference is: -250.03848
# Maximum value NDVI difference is: 335.55753
# array([[-0.03238474, -0.10961682, -0.13379247, ..., -0.0616141 ,
#         -0.0533012 , -0.05479926],
#        [ 0.06322704, -0.02374098, -0.12805215, ..., -0.06135162,
#         -0.05291503, -0.05425509],
#        [ 0.05626818, -0.10890485, -0.12321831, ..., -0.0554959 ,
#         -0.04975665, -0.05105515],
#        ...,
#        [-0.06871685, -0.07789949, -0.06122144, ..., -0.13554038,
#         -0.11095714, -0.06128987],
#        [-0.06567086, -0.07443379, -0.07148691, ..., -0.05926633,
#         -0.04544847, -0.04115398],
#        [-0.0615597 , -0.06022453, -0.07335809, ..., -0.03445601,
#         -0.03301596, -0.04464709]], dtype=float32)

# %%
plotImage(NDVIchange)

# %% [markdown]
# Define a hreshold

# %%
reproj = gdal.Warp("output.tif", NDVIchange, dstSRS = "EPSG:32613" )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [66], in <cell line: 1>()
# ----> 1 reproj = gdal.Warp("output.tif", NDVIchange, dstSRS = "EPSG:32613" )
#
# File ~\anaconda3\lib\site-packages\osgeo\gdal.py:673, in Warp(destNameOrDestDS, srcDSOrSrcDSTab, **kwargs)
#     670     srcDSTab = [srcDSOrSrcDSTab]
#     672 if isinstance(destNameOrDestDS, str):
# --> 673     return wrapper_GDALWarpDestName(destNameOrDestDS, srcDSTab, opts, callback, callback_data)
#     674 else:
#     675     return wrapper_GDALWarpDestDS(destNameOrDestDS, srcDSTab, opts, callback, callback_data)
#
# File ~\anaconda3\lib\site-packages\osgeo\gdal.py:4215, in wrapper_GDALWarpDestName(*args)
#    4213 def wrapper_GDALWarpDestName(*args):
# ...

# %%
#NDVIchange[(NDVIchange >= 0.15) & (NDVIchange < 0.33)] = 1
#NDVIchange[NDVIchange <= 0.15] = 0

NDVIchange_thres =  np.where((NDVIchange>=0.15) & (NDVIchange<=0.33),1,0)
#NDVIchange_thre = np.where((NDVIchange>0.15)&(NDVIchange<0.33)) 


fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 15))
im = ax.imshow(NDVIchange_thres)
ax.set_xticks([])
ax.set_yticks([])

#plotImage(NDVIchange_thres)
# Out:
# []

# %% [markdown]
# Mask out the area of change

# %%
total = NDVIchange.sum()
count_pixels = (NDVIchange_thres == 1).sum()
affected_area_square_m = count_pixels * 100
print(total)
print(count_pixels)
print(affected_area_square_m)
# Out:
# -184.40903
# 7604
# 760400

# %%
import numpy as np

values = np.array([1,2,3,4,5])

result = values[np.where((values>2) & (values<4))]
print(result)
# Out:
# [3]

# %%
from typing import Any, Optional, Tuple

def plot_image2(
    image: np.ndarray, factor: float = 1.0, clip_range: Optional[Tuple[float, float]] = None, **kwargs: Any) -> None:
    """Utility function for plotting RGB images."""
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 15))
    #if clip_range is not None:
    #    im = ax.imshow(np.clip(image * factor, *clip_range), **kwargs)
    #else:
    im = ax.imshow(image * factor, **kwargs, vmin=-1.0, vmax=1.0)
    cbar = fig.colorbar(im)
    ax.set_xticks([])
    ax.set_yticks([])
    #lims = ax.imshow(im, vmin=-1.0, vmax=1.0)
    #cbar = fig.colorbar(lims, label = 'NDVI change')
   # plt.show()

# %%
plot_image2(NDVIchange)

# %% [markdown]
# OBTAIN STATISTICS FOR CHANGE DETECTION

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 15))
im = ax.imshow(NDVIchange, vmin=-1.0, vmax=1.0)
cbar = fig.colorbar(im)
ax.set_xticks([])
ax.set_yticks([])
    #lims = ax.imshow(im, vmin=-1.0, vmax=1.0)
    #cbar = fig.colorbar(lims, label = 'NDVI change')
   # plt.show()
# Out:
# []
